# %%
import pandas as pd
import numpy as np
cars = pd.read_csv('Data_Car_Price.csv', sep = ",")

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

cars["normalized-losses"] = cars['normalized-losses'].replace('?', np.NaN) 
cars['normalized-losses'] = pd.to_numeric(cars['normalized-losses'], errors='coerce')
cars["normalized-losses"] = cars['normalized-losses'].fillna(cars['normalized-losses'].mean()) 
cars["stroke"] = cars['stroke'].replace('?', np.NaN)
cars["bore"] = cars['bore'].replace('?', np.NaN)
cars["horsepower"] = cars['horsepower'].replace('?', np.NaN)
cars["peak-rpm"] = cars['peak-rpm'].replace('?', np.NaN)
cars["price"] = cars['price'].replace('?', np.NaN)

cars["price"] = cars["price"].astype(float)
cars
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3              122.0    alfa-romero       gas        std
# 1            3              122.0    alfa-romero       gas        std
# 2            1              122.0    alfa-romero       gas        std
# 3            2              164.0           audi       gas        std
# 4            2              164.0           audi       gas        std
# 5            2              122.0           audi       gas        std
# 6            1              158.0           audi       gas        std
# 7            1              122.0           audi       gas        std
# 8            1              158.0           audi       gas      turbo
# 9            0              122.0           audi       gas      turbo
# 10           2              192.0            bmw       gas        std
# 11           0              192.0            bmw       gas        std
# ...

# %%
cars.loc[(cars['fuel-type'] == "gas") & (cars["aspiration"] == "turbo") & (cars['num-of-doors'] == "two") & (cars["body-style"] == "hatchback") & (cars["peak-rpm"] == "5500")][(cars['fuel-type'] == "gas") & (cars["aspiration"] == "turbo") & (cars['num-of-doors'] == "two") & (cars["body-style"] == "hatchback") & (cars["peak-rpm"] == "5500")]
cars1 = cars.loc[(cars['fuel-type'] == "gas") & (cars["aspiration"] == "turbo") & (cars['num-of-doors'] == "two") & (cars["body-style"] == "hatchback") & (cars["peak-rpm"] == "5500") & (cars["compression-ratio"]  < 8.0) & (cars["horsepower"] == "102")]
cars1["price"].mean()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 7867.666666666667

# %%
#cylindré

cars["stroke"] = cars["stroke"].astype(float)
cars[cars['horsepower'].isnull()]
cars['horsepower'] = cars['horsepower'].astype(float)
HP = cars.loc[(cars['compression-ratio'] == 8.70) & (cars['curb-weight'] < 2600) & (cars['stroke'] > 2.64)]
HP['horsepower'].mean()
# Out:
# 92.0

# %%
#  Pandas fonctionnement

max = 0
count = 0
for i in range(len(cars)):
    if i != 9:
        if cars.aspiration[i] == cars.aspiration[9]:
            count = count + 1
        if cars['num-of-doors'][i] == cars['num-of-doors'][9]:
            count = count + 1
        if cars['body-style'][i] == cars['body-style'][9]:
            count = count + 1
        if cars['peak-rpm'][i] == cars['peak-rpm'][9]:
            count = count + 1
        if  cars['compression-ratio'][i] < cars['compression-ratio'][9]:
            count = count + 1
        if cars.horsepower[i] == cars.horsepower[9]:
            count = count + 1
        if count > max:
            max = count
            print(i)
    count = 0
print('partie 2')
for i in range(len(cars)):
    if i != 9:
        if cars.aspiration[i] == cars.aspiration[9]:
            count = count + 1
        if cars['num-of-doors'][i] == cars['num-of-doors'][9]:
            count = count + 1
        if cars['body-style'][i] == cars['body-style'][9]:
            count = count + 1
        if cars['peak-rpm'][i] == cars['peak-rpm'][9]:
            count = count + 1
        if  cars['compression-ratio'][i] < cars['compression-ratio'][9]:
            count = count + 1
        if cars.horsepower[i] == cars.horsepower[9]:
            count = count + 1
        if count == max:
            print(i)
        count = 0
# Out:
# 0
# 2
# 21
# 23
# 136
# partie 2
# 136

# %%
cars['num-of-doors'] = cars['num-of-doors'].replace('?', cars['num-of-doors'].value_counts().idxmax())

cars["num-of-doors"]
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
# 5       two
# 6      four
# 7      four
# 8      four
# 9       two
# 10      two
# 11     four
# 12      two
# 13     four
# 14     four
# 15     four
# 16      two
# 17     four
# 18      two
# 19      two
# 20     four
# 21      two
# 22      two
# 23      two
# 24     four
# 25     four
# 26     four
# 27     four
# 28     four
# 29      two
# 30      two
# 31      two
# 32      two
# 33      two
# 34      two
# 35     four
# 36     four
# 37      two
# 38      two
# 39     four
# 40     four
# 41     four
# 42      two
# 43     four
# 44      two
# 45     four
# 46      two
# 47     four
# 48     four
# 49      two
# 50      two
# 51      two
# 52      two
# 53     four
# 54     four
# 55      two
# 56      two
# 57      two
# 58      two
# 59      two
# 60     four
# 61      two
# 62     four
# 63     four
# 64     four
# 65     four
# 66     four
# 67     four
# 68     four
# 69      two
# 70     four
# ...

# %%
cars = cars.dropna(subset=['price'])

# %%
# Bore, stroke, peak-rpm et price en float (déja bon), normalized-losses en int

cars["bore"] = cars["bore"].astype(float)
cars["peak-rpm"] = cars["peak-rpm"].astype(float)
cars["normalized-losses"] = cars["normalized-losses"].astype(int)
cars.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-bae            float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# Il est parfois utile pour la compréhension des données de convertir les unités utilisées. C’est le cas, ici, pour la consommation qui est mesurée en mpg (miles per gallon).
# Convertir les colonnes concernées en L/100 km et les renommer. (L/100 km = 235/mpg)
 

cars["highway-100kml"] = 235.215/cars["highway-mpg"].values
cars["city-100kml"] = 235.215/cars["city-mpg"].values

# %%
cars.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-bae            float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# highway-100kml       float64
# city-100kml          float64
# dtype: object

# %%
import seaborn as sns

# standarzed : 𝑥−𝑥.𝑚𝑒𝑎𝑛𝑥.𝑠𝑡𝑑/𝑥.𝑠𝑡𝑑 :

standartized_cars_length=(cars["length"]-cars["length"].mean())/cars["length"].std()
sns.distplot(standartized_cars_length)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# normalized : 𝑥−𝑥.𝑚𝑖𝑛/𝑥.𝑚𝑎𝑥−𝑥.𝑚𝑖𝑛 : 

normalized_cars_length=(cars["length"]-cars["length"].min())/(cars["length"].max()-cars["length"].min())

normalized_cars_width=(cars["width"]-cars["width"].min())/(cars["width"].max()-cars["width"].min())

normalized_cars_height=(cars["height"]-cars["height"].min())/(cars["height"].max()-cars["height"].min())


sns.distplot(normalized_cars_length, hist=False)
sns.distplot(normalized_cars_width, hist=False)
sns.distplot(normalized_cars_height, hist=False)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
cars["category"] = pd.cut(cars['horsepower'], bins = 3, labels=["fort", "moyen", "faible"])
    
cars.head
# Out:
# <bound method NDFrame.head of      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                122    alfa-romero       gas        std
# 1            3                122    alfa-romero       gas        std
# 2            1                122    alfa-romero       gas        std
# 3            2                164           audi       gas        std
# 4            2                164           audi       gas        std
# 5            2                122           audi       gas        std
# 6            1                158           audi       gas        std
# 7            1                122           audi       gas        std
# 8            1                158           audi       gas      turbo
# 9            0                122           audi       gas      turbo
# 10           2                192            bmw       gas        std
# 11           0                192            bmw       gas        std
# ...

# %%
cars['fuel-type'] = pd.get_dummies(cars['fuel-type'])
cars.head(5)
# Out:
#    symboling  normalized-losses         make  fuel-type aspiration  \
# 0          3                122  alfa-romero          0        std
# 1          3                122  alfa-romero          0        std
# 2          1                122  alfa-romero          0        std
# 3          2                164         audi          0        std
# 4          2                164         audi          0        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-bae  length  \
# 0          two  convertible          rwd           front       88.6   168.8
# 1          two  convertible          rwd           front       88.6   168.8
# 2          two    hatchback          rwd           front       94.5   171.2
# 3         four        sedan          fwd           front       99.8   176.6
# 4         four        sedan          4wd           front       99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
import matplotlib.pyplot as plt

cars.boxplot(column=["price"], by = "drive-wheels")
plt.show()

# %%
import seaborn as sns
ax = sns.regplot(x="city-mpg", y="price", data=cars)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
cars.corr()
# Out:
#                    symboling  normalized-losses  wheel-bae    length  \
# symboling           1.000000           0.465190  -0.531954 -0.357612
# normalized-losses   0.465190           1.000000  -0.056518  0.019209
# wheel-bae          -0.531954          -0.056518   1.000000  0.874587
# length             -0.357612           0.019209   0.874587  1.000000
# width              -0.232919           0.084195   0.795144  0.841118
# height             -0.541038          -0.370706   0.589435  0.491029
# curb-weight        -0.227691           0.097785   0.776386  0.877728
# engine-size        -0.105790           0.110997   0.569329  0.683360
# stroke             -0.008965           0.055363   0.161477  0.129739
# compression-ratio  -0.178515          -0.114525   0.249786  0.158414
# horsepower          0.071622           0.203434   0.352297  0.555003
# city-mpg           -0.035823          -0.218749  -0.470414 -0.670909
# highway-mpg         0.034606          -0.178221  -0.544082 -0.704662
# ...

# %%
# Code en plus

export_excel = voiture_normalize.to_excel (r'C:\Users\Dell\Documents\PROJET VOITURE\export_dataframe.xlsx', index = None, header=True)

cars.corr()


import matplotlib.pyplot as plt
import numpy as np
cars.boxplot(["horsepower"])
plt.show()

tut = np.where(voiture['price'] == "?",,voiture['price'])

print(tut)


import seaborn as sns
x = cars[['fuel-type', "aspiration", 'num-of-doors', "body-style", "peak-rpm", "compression-ratio", "horsepower"]]
cars4.loc[9:x]



Normalize total_bedrooms column
x_array = np.array(df['total_bedrooms'])
normalized_X = preprocessing.normalize([x_array])
